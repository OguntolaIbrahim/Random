# %%
import openpyxl as xl

info=xl.load_workbook('C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\Book1.xlsx')
sample=xl.load_workbook('C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\Sample.xlsx')
infosheet=info['Sheet1']
samplesheet=sample['Information']

for row in range(1,infosheet.max_row+1):
    customer=infosheet.cell(row,1)
#     cell2=samplesheet['a1']
    cell2=samplesheet['b12']
    cell2=customer.value
    cell3=samplesheet['b13']
    cell3=customer.value
    capacity=infosheet.cell(row,5)
    samplesheet['b15']=capacity.value
    serial_no=infosheet.cell(row,3)
    samplesheet['b17']=serial_no.value
    samplesheet['b18']=serial_no.value
    gem_port=infosheet.cell(row,9)
    gem_id=infosheet.cell(row,10)
    vlan=infosheet.cell(row,4)
    samplesheet['b20']=gem_port.value
    samplesheet['b21']=gem_id.value
    samplesheet['b23']=vlan.value
    service=infosheet.cell(row,6)
    samplesheet['b14']=service.value
    
    sample.save(f'C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\{cell2}.xlsx')
                                                                                                  
    #gbph port skipped
    
    

    print(cell2)
# Out:
#   File "<ipython-input-44-72a302da1f9b>", line 29
#     sample.save(f'C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\{cell2}{samplesheet['b14']}.xlsx')
#                                                                                                                   ^
# SyntaxError: invalid syntax

# %%
import openpyxl as xl

info=xl.load_workbook('C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\handex.xlsx')
sample=xl.load_workbook('C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\Sample.xlsx')
infosheet=info['infosheet']
samplesheet=sample['Information']

for row in range(2,infosheet.max_row+1):
    customer=infosheet.cell(row,1)
#     cell2=samplesheet['a1']
    a=customer.value
    samplesheet['b12']=customer.value
    port=infosheet.cell(row,10)
    samplesheet['b22']=port.value
    location=infosheet.cell(row,14)
    samplesheet['b13']=location.value
    capacity=infosheet.cell(row,4)
    samplesheet['b15']=capacity.value
    serial_no=infosheet.cell(row,2)
    samplesheet['b17']=serial_no.value
    samplesheet['b18']=capacity.value
    gem_port=infosheet.cell(row,8)
    gem_id=infosheet.cell(row,7)
    vlan=infosheet.cell(row,3)
    samplesheet['b20']=gem_port.value
    samplesheet['b21']=gem_id.value
    samplesheet['b23']=vlan.value
    service=infosheet.cell(row,5)
    samplesheet['b14']=service.value
    s=service.value
    pop=infosheet.cell(row,11)
    samplesheet['b26']=pop.value
    slot=infosheet.cell(row,9)
    samplesheet['b29']=slot.value
    mgmt=infosheet.cell(row,12)
    samplesheet['b24']=mgmt.value
    date=infosheet.cell(row,13)
    samplesheet['b6']=date.value
    samplesheet['b7']=date.value
    
    
    sample.save(f'C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\Gen\\Service Handover GPON for {a} {capacity.value} {service.value}.xlsx')
    
    #gbph port skipped
    
    

    print(customer.value)
# Out:
# Expereo International Opebi
# Keystone Bank Limited DR KUDIRAT
# Keystone Bank Limited HQ
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
import openpyxl as xl

info=xl.load_workbook('C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\handover_migration.xlsx')
sample=xl.load_workbook('C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\Sample.xlsx')
infosheet=info['Sheet2']
samplesheet=sample['Information']

for row in range(1,infosheet.max_row+1):
    customer=infosheet.cell(row,1)
#     cell2=samplesheet['a1']
    date=infosheet.cell(row,16)
    samplesheet['b6']=date.value
    samplesheet['b7']=date.value
    a=customer.value
    samplesheet['b12']=customer.value
    port=infosheet.cell(row,15)
    samplesheet['b22']=port.value
    samplesheet['b13']='Ikeja'
    capacity=infosheet.cell(row,5)
    samplesheet['b15']=capacity.value
    serial_no=infosheet.cell(row,3)
    samplesheet['b17']=serial_no.value
    samplesheet['b18']=capacity.value
    gem_port=infosheet.cell(row,9)
    gem_id=infosheet.cell(row,10)
    vlan=infosheet.cell(row,4)
    samplesheet['b20']=gem_port.value
    samplesheet['b21']=gem_id.value
    samplesheet['b23']=vlan.value
    service=infosheet.cell(row,6)
    samplesheet['b14']=service.value
    s=service.value
    slot=infosheet.cell(row,13)
    samplesheet['b29']=slot.value
    
    sample.save(f'C:\\Users\\ibrahim.oguntola\\OneDrive - mainone.net\\Desktop\\excel gen\\Handover Document list\\Service Handover of Huawei GPON for {a} {s}.xlsx')
    
    #gbph port skipped
    
    

    print(cell2)
# Out:
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# LASUTH-NCDC IKEJA
# ...
